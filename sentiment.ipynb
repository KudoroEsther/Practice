# %%
from datasets import load_dataset
import pandas as pd

# %%
dataset = load_dataset("andrea-t94/TwitterSentiment140")

# %%
dataset.to_csv("TwitterSentiment140.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dataset.to_csv("TwitterSentiment140.csv", index=False)
#
# AttributeError: 'IterableDatasetDict' object has no attribute 'to_csv'
